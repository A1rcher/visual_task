# %%
import numpy
import matplotlib.pyplot as plt
from testCases import *
import sklearn
import sklearn.datasets
import sklearn.linear_model
from planar_utils import *

# %matplotlib inline

np.random.seed(1)

# %%
X, Y = load_planar_dataset()

print(X.shape)
print(Y.shape)

# plt.scatter(X[0, :], X[1, :], c=Y, s=40, cmap=plt.cm.Spectral)
# Out:
# (2, 400)
# (1, 400)

# %%
clf = sklearn.linear_model.LogisticRegressionCV()
clf.fit(X.T, Y.T)

plot_decision_boundary(lambda x: clf.predict(x), X, Y)
plt.title("Logistic Regression")
LR_predictions = clf.predict(X.T)
print(f"逻辑回归的准确性：{float((np.dot(Y, LR_predictions) + np.dot(1-Y, 1-LR_predictions)) / float(Y.size) * 100)}%")
# Out:
# /home/archer/.local/lib/python3.8/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 逻辑回归的准确性：47.0%

# %%
def layer_sizes(X, Y):
    n_x = X.shape[0]
    n_h = 4
    n_y = Y.shape[0]
    
    return n_x, n_h, n_y

# %%
print("-------测试layer_sizes--------")
X_asses, Y_asses = layer_sizes_test_case()
n_x, n_h, n_y = layer_sizes(X_asses, Y_asses)
print(f"n_x:{n_x}")
print(f"n_h:{n_h}")
print(f"n_y:{n_y}")
# Out:
# -------测试layer_sizes--------
# n_x:5
# n_h:4
# n_y:2

# %%
def init_w_b(n_x, n_h, n_y):
    np.random.seed(2)
    W1 = np.random.randn(n_h, n_x) * 0.01
    b1 = np.zeros(shape=(n_h, 1))
    W2 = np.random.randn(n_y, n_h) * 0.01
    b2 = np.zeros(shape=(n_y, 1))
    
    assert(W1.shape == (n_h, n_x))
    assert(b1.shape == (n_h, 1))
    assert(W2.shape == (n_y, n_h))
    assert(b2.shape == (n_y, 1))
    
    parameters={
        "W1": W1,
        "b1": b1,
        "W2": W2,
        "b2": b2
    }
    
    return parameters

# %%
print("--------测试init_w_b---------")
n_x, n_h, n_y = initialize_parameters_test_case()
parameters = init_w_b(n_x, n_h, n_y)

print(f"W1 = {parameters['W1']}")
print(f"b1 = {parameters['b1']}")
print(f"W2 = {parameters['W2']}")
print(f"b2 = {parameters['b2']}")
# Out:
# --------测试init_w_b---------
# W1 = [[-0.00416758 -0.00056267]
#  [-0.02136196  0.01640271]
#  [-0.01793436 -0.00841747]
#  [ 0.00502881 -0.01245288]]
# b1 = [[0.]
#  [0.]
#  [0.]
#  [0.]]
# W2 = [[-0.01057952 -0.00909008  0.00551454  0.02292208]]
# b2 = [[0.]]

# %%
def forward_propagation(X, parameters):
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    
    Z1 = np.dot(W1, X) + b1
    A1 = np.tanh(Z1)
    Z2 = np.dot(W2, A1) + b2
    A2 = sigmoid(Z2)
    
    assert(A2.shape == (1, X.shape[1]))
    
    cache = {
        'Z1': Z1,
        'A1': A1,
        'Z2': Z2,
        'A2': A2
    }
    
    return A2, cache

# %%
print("-------测试forward_propagation------")
X_assess, parameters = forward_propagation_test_case()
A2, cache = forward_propagation(X_assess, parameters)
print(np.mean(cache['Z1']))
print(np.mean(cache['A1']))
print(np.mean(cache['Z2']))
print(np.mean(cache['A2']))
# Out:
# -------测试forward_propagation------
# -0.0004997557777419913
# -0.000496963353231779
# 0.00043818745095914653
# 0.500109546852431

# %%
def compute_cost(A2, Y, parameters):
    m = Y.shape[1]
    W1 = parameters['W1']
    W2 = parameters['W2']
    
    logprobs = np.multiply(np.log(A2), Y) + np.multiply((1 - Y), np.log(1 - A2))
    cost = - np.sum(logprobs) / m
    cost = float(np.squeeze(cost))
    
    return cost

# %%
print("-------测试compute_cost--------")
A2, Y, parameters = compute_cost_test_case()
print(f'cost = {compute_cost(A2, Y, parameters)}')
# Out:
# -------测试compute_cost--------
# cost = 0.6929198937761266

# %%
def backward_propagation(parameters, cache, X, Y):
    m = X.shape[1]
    
    W1 = parameters['W1']
    W2 = parameters['W2']
    
    A1 = cache['A1']
    A2 = cache['A2']
    
    dZ2 = A2 - Y
    dW2 = (1 / m) * np.dot(dZ2, A1.T)
    db2 = (1 / m) * np.sum(dZ2, axis=1, keepdims=True)
    dZ1 = np.multiply(np.dot(W2.T, dZ2), 1 - np.power(A1, 2))
    dW1 = (1 / m) * np.dot(dZ1, X.T)
    db1 = (1 / m) * np.sum(dZ1, axis=1, keepdims=True)
    grads = {
        'dW1': dW1,
        'db1': db1,
        'dW2': dW2,
        'db2': db2
    }
    
    return grads

# %%
print("-------测试backward_propagation------")
parameters, cache, X, Y = backward_propagation_test_case()
grads = backward_propagation(parameters, cache, X, Y)

print(f"dW1 = {grads['dW1']}")
print(f"db1 = {grads['db1']}")
print(f"dW2 = {grads['dW2']}")
print(f"db2 = {grads['db2']}")
# Out:
# -------测试backward_propagation------
# dW1 = [[ 0.01018708 -0.00708701]
#  [ 0.00873447 -0.0060768 ]
#  [-0.00530847  0.00369379]
#  [-0.02206365  0.01535126]]
# db1 = [[-0.00069728]
#  [-0.00060606]
#  [ 0.000364  ]
#  [ 0.00151207]]
# dW2 = [[ 0.00363613  0.03153604  0.01162914 -0.01318316]]
# db2 = [[0.06589489]]

# %%
def update_parameters(parameters, grads, learning_rate=1.2):
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    
    dW1 = grads['dW1']
    db1 = grads['db1']
    dW2 = grads['dW2']
    db2 = grads['db2']
    
    W1 = W1 - learning_rate * dW1
    b1 = b1 - learning_rate * db1
    W2 = W2 - learning_rate * dW2
    b2 = b2 - learning_rate * db2
    
    parameters = {
        'W1': W1,
        'b1': b1,
        'W2': W2,
        'b2': b2        
    }
    
    return parameters

# %%
print("------测试update_parameters------")
parameters, grads = update_parameters_test_case()
parameters = update_parameters(parameters, grads, learning_rate=1.2)
print(f"W1 = {parameters['W1']}")
print(f"b1 = {parameters['b1']}")
print(f"W2 = {parameters['W2']}")
print(f"b2 = {parameters['b2']}")
# Out:
# ------测试update_parameters------
# W1 = [[-0.00643025  0.01936718]
#  [-0.02410458  0.03978052]
#  [-0.01653973 -0.02096177]
#  [ 0.01046864 -0.05990141]]
# b1 = [[-1.02420756e-06]
#  [ 1.27373948e-05]
#  [ 8.32996807e-07]
#  [-3.20136836e-06]]
# W2 = [[-0.01041081 -0.04463285  0.01758031  0.04747113]]
# b2 = [[0.00010457]]

# %%
def nn_model(X, Y, n_h, num_iterations=10000, print_cost=False):
    np.random.seed(3)
    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]
    
    parameters = init_w_b(n_x, n_h, n_y)
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    
    for i in range(num_iterations):
        A2, cache = forward_propagation(X, parameters)
        cost = compute_cost(A2, Y, parameters)
        grads = backward_propagation(parameters, cache, X, Y)
        parameters = update_parameters(parameters, grads)
        
        if print_cost:
            if i % 1000 == 0:
                print(f"迭代次数：{i}，损失值：{cost}")
        
    return parameters

# %%
print("------测试nn_model--------")
X_assess, Y_assess = nn_model_test_case()
parameters = nn_model(X_assess, Y_assess, 4, num_iterations=10000, print_cost=False)
print(f"W1 = {parameters['W1']}")
print(f"b1 = {parameters['b1']}")
print(f"W2 = {parameters['W2']}")
print(f"b2 = {parameters['b2']}")
# Out:
# ------测试nn_model--------
# /tmp/ipykernel_9585/153278334.py:6: RuntimeWarning: divide by zero encountered in log
#   logprobs = np.multiply(np.log(A2), Y) + np.multiply((1 - Y), np.log(1 - A2))
# /home/archer/visual_task/DeepLearning/learning_with_AndrewNg/week3_task/planar_utils.py:34: RuntimeWarning: overflow encountered in exp
#   s = 1/(1+np.exp(-x))
# W1 = [[-3.89167767  4.77541602]
#  [-6.77960338  1.20272585]
#  [-3.88338966  4.78028666]
#  [ 6.77958203 -1.20272575]]
# b1 = [[ 2.11530892]
#  [ 3.41221357]
#  [ 2.11585732]
#  [-3.41221322]]
# W2 = [[-2512.9093032  -2502.70799785 -2512.01655969  2502.65264416]]
# b2 = [[-22.29071761]]

# %%
def predict(parameters, X):
    A2, cache = forward_propagation(X, parameters)
    predictions = np.round(A2)
    
    return predictions

# %%
print('-------测试predict------')
parameters, x_assess = predict_test_case()
predictions = predict(parameters, X_assess)
print(np.mean(predictions))
# Out:
# -------测试predict------
# 0.6666666666666666

# %%
parameters = nn_model(X, Y, n_h=4, num_iterations=10000, print_cost=True)

plot_decision_boundary(lambda x: predict(parameters, x.T), X, Y)
plt.title("Decision Boundary for hidden layer size 4")
predictions = predict(parameters, X)
print(f"准确率：{float((np.dot(Y, predictions.T) + np.dot(1 - Y, 1 - predictions.T)) / float(Y.size) * 100)} %")
# Out:
# 迭代次数：0，损失值：0.6925839035679378
# 迭代次数：1000，损失值：-inf
# 迭代次数：2000，损失值：-inf
# 迭代次数：3000，损失值：-inf
# 迭代次数：4000，损失值：-inf
# 迭代次数：5000，损失值：-inf
# 迭代次数：6000，损失值：-inf
# 迭代次数：7000，损失值：-inf
# /tmp/ipykernel_9585/153278334.py:6: RuntimeWarning: divide by zero encountered in log
#   logprobs = np.multiply(np.log(A2), Y) + np.multiply((1 - Y), np.log(1 - A2))
# 迭代次数：8000，损失值：-inf
# 迭代次数：9000，损失值：-inf
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[253], line 3
#       1 parameters = nn_model(X, Y, n_h=4, num_iterations=10000, print_cost=True)
# ----> 3 plot_decision_boundary(lambda x: predict(parameters, x.T), X, Y)
#       4 plt.title("Decision Boundary for hidden layer size 4")
#       5 predictions = predict(parameters, X)
#
# File ~/visual_task/DeepLearning/learning_with_AndrewNg/week3_task/planar_utils.py:21, in plot_decision_boundary(model, X, y)
#      19 plt.ylabel('x2')
#      20 plt.xlabel('x1')
# ---> 21 plt.scatter(X[0, :], X[1, :], c=y, cmap=plt.cm.Spectral)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2865         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2866         **({"data": data} if data is not None else {}), **kwargs)
#    2867     sci(__ret)
#    2868     return __ret
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# -> 1446         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448     bound = new_sig.bind(ax, *args, **kwargs)
#    1449     auto_label = (bound.arguments.get(label_namer)
#    1450                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py:4596, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4593 if edgecolors is None:
#    4594     orig_edgecolor = kwargs.get('edgecolor', None)
#    4595 c, colors, edgecolors = \
# -> 4596     self._parse_scatter_color_args(
#    4597         c, edgecolors, kwargs, x.size,
#    4598         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4600 if plotnonfinite and colors is None:
#    4601     c = np.ma.masked_invalid(c)
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/axes/_axes.py:4433, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4431 if not c_is_mapped:
#    4432     try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4433         colors = mcolors.to_rgba_array(c)
#    4434     except (TypeError, ValueError) as err:
#    4435         if "RGBA values should be within 0-1 range" in str(err):
#
# File ~/.local/lib/python3.8/site-packages/matplotlib/colors.py:454, in to_rgba_array(c, alpha)
#     452         result[mask] = 0
#     453     if np.any((result < 0) | (result > 1)):
# --> 454         raise ValueError("RGBA values should be within 0-1 range")
#     455     return result
#     456 # Handle single values.
#     457 # Note that this occurs *after* handling inputs that are already arrays, as
#     458 # `to_rgba(c, alpha)` (below) is expensive for such inputs, due to the need
#     459 # to format the array in the ValueError message(!).
#
# ValueError: RGBA values should be within 0-1 range
